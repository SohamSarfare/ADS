# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/My Drive/ADS/')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Environment Setup
# Installing dependencies `mxnet` `opencv` `easydict` and `Cython`

# %%
# !pip install mxnet-cu101
# !pip install opencv-python
# !pip install easydict
# !pip install Cython
# Out:
# ...
#      |███████████████████████████████▌| 834.1MB 1.2MB/s eta 0:00:11tcmalloc: large alloc 1147494400 bytes == 0x38b08000 @  0x7f18e5cff615 0x591f47 0x4cc229 0x4cc38b 0x50a51c 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x58e793 0x50c467 0x58e793 0x50c467 0x58e793 0x50c467 0x58e793 0x50c467 0x509918 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x509918 0x50a64d
#      |████████████████████████████████| 846.0MB 21kB/s
# ...
#   Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ...

# %% [markdown]
# Verifying installation of `mxnet` using GPU

# %%
import mxnet as mx
a = mx.nd.ones((2, 3), mx.gpu())

# %% [markdown]
# Unzipping Source code and data and executing the make file to setup environment variables.

# %%
# !unzip RetinaFace.zip

# %%
# %cd RetinaFace
# !make
# Out:
# /content/gdrive/My Drive/ADS/RetinaFace
# cd rcnn/cython/; python setup.py build_ext --inplace; rm -rf build; cd ../../
# running build_ext
# skipping 'bbox.c' Cython extension (up-to-date)
# skipping 'anchors.c' Cython extension (up-to-date)
# skipping 'cpu_nms.c' Cython extension (up-to-date)
# skipping 'gpu_nms.cpp' Cython extension (up-to-date)
# cd rcnn/pycocotools/; python setup.py build_ext --inplace; rm -rf build; cd ../../
# running build_ext

# %% [markdown]
# # Testing on Source Data
#
# Using the pretrained model provided by the authors, the model is tested on the original WIDER_Face dataset.

# %%
# !python test_widerface.py --prefix './model/R50' --mode=0
# Out:
# INFO:root:Called with argument: Namespace(bbox_vote=False, dataset='retinaface', dataset_path='./data/retinaface', epoch=0, gpu=0, image_set='val', mode=0, network='net3', nocrop=False, output='./wout', part=0, parts=1, prefix='./model/R50', pyramid=False, root_path='./data', thresh=0.02)
# test with Namespace(bbox_vote=False, dataset='retinaface', dataset_path='./data/retinaface', epoch=0, gpu=0, image_set='val', mode=0, network='net3', nocrop=False, output='./wout', part=0, parts=1, prefix='./model/R50', pyramid=False, root_path='./data', thresh=0.02)
# [32, 16, 8] {'32': {'SCALES': (32, 16), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '16': {'SCALES': (8, 4), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '8': {'SCALES': (2, 1), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}}
# [02:39:21] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v1.3.0. Attempting to upgrade...
# ...

# %%
# !python test_widerface.py --prefix './model/R50' --mode=1
# Out:
# INFO:root:Called with argument: Namespace(bbox_vote=True, dataset='retinaface', dataset_path='./data/retinaface', epoch=0, gpu=0, image_set='val', mode=1, network='net3', nocrop=False, output='./wout', part=0, parts=1, prefix='./model/R50', pyramid=True, root_path='./data', thresh=0.02)
# test with Namespace(bbox_vote=True, dataset='retinaface', dataset_path='./data/retinaface', epoch=0, gpu=0, image_set='val', mode=1, network='net3', nocrop=False, output='./wout', part=0, parts=1, prefix='./model/R50', pyramid=True, root_path='./data', thresh=0.02)
# [32, 16, 8] {'32': {'SCALES': (32, 16), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '16': {'SCALES': (8, 4), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '8': {'SCALES': (2, 1), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}}
# [09:39:13] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v1.3.0. Attempting to upgrade...
# ...

# %%
# !python test.py
# Out:
# [32, 16, 8] {'32': {'SCALES': (32, 16), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '16': {'SCALES': (8, 4), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '8': {'SCALES': (2, 1), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}}
# [04:18:59] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v1.3.0. Attempting to upgrade...
# [04:18:59] src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# means [0. 0. 0.]
# use_landmarks True
# cascade 0
# sym size: 9
# (2448, 3264, 3)
# im_scale 0.41830065359477125
# [04:19:03] src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# 0 (3, 5) (3, 5, 2)
# find 3 faces
# writing ./detector_test.jpg

# %% [markdown]
# # Clean-up
# Removing source code to free up space in google drive

# %%
# %cd ..
# !rm -rf RetinaFace
# !ls
